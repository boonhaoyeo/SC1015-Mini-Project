# %% [markdown]
# # Exploratory Data Analysis on the AirBnB data

# %% [markdown]
# ### Importing of Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics


from sklearn.utils import resample

from collections import Counter
air_data = pd.read_csv("listings_june.csv")
zhdf = pd.read_csv("listings_june.csv")

air_data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  49091  https://www.airbnb.com/rooms/49091  20210629180711   2021-06-30
# 1  50646  https://www.airbnb.com/rooms/50646  20210629180711   2021-06-30
# 2  56334  https://www.airbnb.com/rooms/56334  20210629180711   2021-06-30
# 3  71609  https://www.airbnb.com/rooms/71609  20210629180711   2021-06-30
# 4  71896  https://www.airbnb.com/rooms/71896  20210629180711   2021-06-30
#
#                                   name  \
# 0    COZICOMFORT LONG TERM STAY ROOM 2
# 1      Pleasant Room along Bukit Timah
# 2                          COZICOMFORT
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
#
#                                          description  \
# 0  <b>The space</b><br />This is Room No. 2.(avai...
# 1  Fully furnished bedroom with a nice view on th...
# 2  <b>The space</b><br />This is Room no. 1. USD7...
# 3  For 3 rooms.Book room 1&2 and room 4<br /><br ...
# 4  <b>The space</b><br />Vocational Stay Deluxe B...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The serenity & quiet surrounding makes it an i...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/24485541/67b0...   266763
# 1  https://a0.muscache.com/pictures/36342984/670d...   227796
# 2  https://a0.muscache.com/pictures/20783922/1966...   266763
# 3  https://a0.muscache.com/pictures/24453191/3580...   367042
# 4  https://a0.muscache.com/pictures/2440674/ac4f4...   367042
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/266763  ...                        5.00
# 1  https://www.airbnb.com/users/show/227796  ...                        4.94
# 2  https://www.airbnb.com/users/show/266763  ...                        5.00
# 3  https://www.airbnb.com/users/show/367042  ...                        4.78
# 4  https://www.airbnb.com/users/show/367042  ...                        4.43
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.00                4.00     NaN                f
# 1                   4.72                4.50     NaN                f
# 2                   4.17                4.67     NaN                f
# 3                   4.26                4.32     NaN                t
# 4                   4.17                4.04     NaN                t
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              2                                           0
# 1                              1                                           0
# 2                              2                                           0
# 3                              4                                           0
# 4                              4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            1
# 2                                            2
# 3                                            4
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.01
# 1                                           0              0.22
# 2                                           0              0.16
# 3                                           0              0.29
# 4                                           0              0.34
#
# [5 rows x 74 columns]

# %% [markdown]
# # Extracting the response

# %%
air_data["review_scores_rating"] = air_data["review_scores_rating"].round(1)
ratings = pd.DataFrame(air_data["review_scores_rating"])
ratings.shape
# Out:
# (4238, 1)

# %%
ratings.isna().sum()
# Out:
# review_scores_rating    1759
# dtype: int64

# %%
air_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4238 non-null   int64
#  1   listing_url                                   4238 non-null   object
#  2   scrape_id                                     4238 non-null   int64
#  3   last_scraped                                  4238 non-null   object
#  4   name                                          4238 non-null   object
#  5   description                                   4091 non-null   object
#  6   neighborhood_overview                         2791 non-null   object
#  7   picture_url                                   4238 non-null   object
#  8   host_id                                       4238 non-null   int64
#  9   host_url                                      4238 non-null   object
#  10  host_name                                     4230 non-null   object
#  11  host_since                                    4230 non-null   object
#  12  host_location                                 4229 non-null   object
#  13  host_about                                    2879 non-null   object
#  14  host_response_time                            3395 non-null   object
#  15  host_response_rate                            3395 non-null   object
#  16  host_acceptance_rate                          3229 non-null   object
#  17  host_is_superhost                             4230 non-null   object
#  18  host_thumbnail_url                            4230 non-null   object
#  19  host_picture_url                              4230 non-null   object
#  20  host_neighbourhood                            3861 non-null   object
#  21  host_listings_count                           4230 non-null   float64
#  22  host_total_listings_count                     4230 non-null   float64
#  23  host_verifications                            4238 non-null   object
#  24  host_has_profile_pic                          4230 non-null   object
#  25  host_identity_verified                        4230 non-null   object
#  26  neighbourhood                                 2791 non-null   object
#  27  neighbourhood_cleansed                        4238 non-null   object
#  28  neighbourhood_group_cleansed                  4238 non-null   object
#  29  latitude                                      4238 non-null   float64
#  30  longitude                                     4238 non-null   float64
#  31  property_type                                 4238 non-null   object
#  32  room_type                                     4238 non-null   object
#  33  accommodates                                  4238 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                4216 non-null   object
#  36  bedrooms                                      3812 non-null   float64
#  37  beds                                          4159 non-null   float64
#  38  amenities                                     4238 non-null   object
#  39  price                                         4238 non-null   object
#  40  minimum_nights                                4238 non-null   int64
#  41  maximum_nights                                4238 non-null   int64
#  42  minimum_minimum_nights                        4237 non-null   float64
#  43  maximum_minimum_nights                        4237 non-null   float64
#  44  minimum_maximum_nights                        4237 non-null   float64
#  45  maximum_maximum_nights                        4237 non-null   float64
#  46  minimum_nights_avg_ntm                        4237 non-null   float64
#  47  maximum_nights_avg_ntm                        4237 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              4238 non-null   object
#  50  availability_30                               4238 non-null   int64
#  51  availability_60                               4238 non-null   int64
#  52  availability_90                               4238 non-null   int64
#  53  availability_365                              4238 non-null   int64
#  54  calendar_last_scraped                         4238 non-null   object
#  55  number_of_reviews                             4238 non-null   int64
#  56  number_of_reviews_ltm                         4238 non-null   int64
#  57  number_of_reviews_l30d                        4238 non-null   int64
#  58  first_review                                  2479 non-null   object
#  59  last_review                                   2479 non-null   object
#  60  review_scores_rating                          2479 non-null   float64
#  61  review_scores_accuracy                        2423 non-null   float64
#  62  review_scores_cleanliness                     2424 non-null   float64
#  63  review_scores_checkin                         2423 non-null   float64
#  64  review_scores_communication                   2424 non-null   float64
#  65  review_scores_location                        2422 non-null   float64
#  66  review_scores_value                           2422 non-null   float64
#  67  license                                       9 non-null      object
#  68  instant_bookable                              4238 non-null   object
#  69  calculated_host_listings_count                4238 non-null   int64
#  70  calculated_host_listings_count_entire_homes   4238 non-null   int64
#  71  calculated_host_listings_count_private_rooms  4238 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   4238 non-null   int64
#  73  reviews_per_month                             2479 non-null   float64
# dtypes: float64(22), int64(17), object(35)
# memory usage: 2.4+ MB

# %%
air_data["price"]=  air_data['price'].str.replace(',', '').str.replace('$', '')
air_data["price"] = pd.to_numeric(air_data["price"], downcast='float')
#air_data = air_data.select_dtypes(exclude=['object'])
#air_data.info()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/174682891.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   air_data["price"]=  air_data['price'].str.replace(',', '').str.replace('$', '')

# %%
#f = plt.figure(figsize=(24, 24))
#sb.heatmap(air_data.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")

# %% [markdown]
# ## All unique amenities in the top 100 rated AirBnB

# %%
top_air = air_data.sort_values(by=['review_scores_rating'])
top_air = top_air[0:100]
top_air.head()
# Out:
#             id                            listing_url       scrape_id  \
# 1350  22458255  https://www.airbnb.com/rooms/22458255  20210629180711
# 949   17899942  https://www.airbnb.com/rooms/17899942  20210629180711
# 1220  21214988  https://www.airbnb.com/rooms/21214988  20210629180711
# 2765  39825497  https://www.airbnb.com/rooms/39825497  20210629180711
# 3665  45779283  https://www.airbnb.com/rooms/45779283  20210629180711
#
#      last_scraped                                           name  \
# 1350   2021-06-29  Cosy Place  with good food in the vicinity  !
# 949    2021-06-29    ~Entire Condo Apartment in Downtown -3 MRTs
# 1220   2021-06-30                                   Luxury place
# 2765   2021-06-30                  Cozy Common Room with Balcony
# 3665   2021-06-30                                   圣淘沙安曼纳圣殿度假酒店
#
#                                             description  \
# 1350  Studio apartment with a queen size bed that is...
# 949   My place is close to the city centre, parks, a...
# 1220  New renovated <br />High tech decor <br />Wind...
# 2765  Close to downtown and very quite and cozy plac...
# 3665  《如果此房间已订满请加我微信：weirenjin888有很多低价酒店名宿，都是会员价》新加坡...
#
#                                   neighborhood_overview  \
# 1350                                                NaN
# 949   [Nearby Places]<br />1. City Square Mall: <br ...
# 1220                                                NaN
# 2765                                                NaN
# 3665                                                NaN
#
#                                             picture_url    host_id  \
# 1350  https://a0.muscache.com/pictures/3d4bcf43-212f...    6578888
# 949   https://a0.muscache.com/pictures/babe501b-992e...   21149720
# 1220  https://a0.muscache.com/pictures/9332d3ed-3c39...  149095282
# 2765  https://a0.muscache.com/pictures/d20e1dad-7392...  153133444
# 3665  https://a0.muscache.com/pictures/60d77986-41d5...  361802160
#
#                                          host_url  ...  \
# 1350    https://www.airbnb.com/users/show/6578888  ...
# 949    https://www.airbnb.com/users/show/21149720  ...
# 1220  https://www.airbnb.com/users/show/149095282  ...
# 2765  https://www.airbnb.com/users/show/153133444  ...
# 3665  https://www.airbnb.com/users/show/361802160  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 1350                         NaN                    NaN                 NaN
# 949                          NaN                    NaN                 NaN
# 1220                         NaN                    NaN                 NaN
# 2765                         NaN                    NaN                 NaN
# 3665                         NaN                    NaN                 NaN
#
#      license instant_bookable calculated_host_listings_count  \
# 1350     NaN                f                              1
# 949      NaN                f                             16
# 1220     NaN                t                              2
# 2765     NaN                t                              1
# 3665     NaN                t                              1
#
#      calculated_host_listings_count_entire_homes  \
# 1350                                           1
# 949                                           16
# 1220                                           0
# 2765                                           0
# 3665                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 1350                                            0
# 949                                             0
# 1220                                            2
# 2765                                            1
# 3665                                            1
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 1350                                           0              0.02
# 949                                            0              0.02
# 1220                                           0              0.05
# 2765                                           0              0.05
# 3665                                           0              0.26
#
# [5 rows x 74 columns]

# %%
top_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1350 to 3226
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            100 non-null    int64
#  1   listing_url                                   100 non-null    object
#  2   scrape_id                                     100 non-null    int64
#  3   last_scraped                                  100 non-null    object
#  4   name                                          100 non-null    object
#  5   description                                   91 non-null     object
#  6   neighborhood_overview                         47 non-null     object
#  7   picture_url                                   100 non-null    object
#  8   host_id                                       100 non-null    int64
#  9   host_url                                      100 non-null    object
#  10  host_name                                     100 non-null    object
#  11  host_since                                    100 non-null    object
#  12  host_location                                 100 non-null    object
#  13  host_about                                    55 non-null     object
#  14  host_response_time                            68 non-null     object
#  15  host_response_rate                            68 non-null     object
#  16  host_acceptance_rate                          59 non-null     object
#  17  host_is_superhost                             100 non-null    object
#  18  host_thumbnail_url                            100 non-null    object
#  19  host_picture_url                              100 non-null    object
#  20  host_neighbourhood                            83 non-null     object
#  21  host_listings_count                           100 non-null    float64
#  22  host_total_listings_count                     100 non-null    float64
#  23  host_verifications                            100 non-null    object
#  24  host_has_profile_pic                          100 non-null    object
#  25  host_identity_verified                        100 non-null    object
#  26  neighbourhood                                 47 non-null     object
#  27  neighbourhood_cleansed                        100 non-null    object
#  28  neighbourhood_group_cleansed                  100 non-null    object
#  29  latitude                                      100 non-null    float64
#  30  longitude                                     100 non-null    float64
#  31  property_type                                 100 non-null    object
#  32  room_type                                     100 non-null    object
#  33  accommodates                                  100 non-null    int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                100 non-null    object
#  36  bedrooms                                      89 non-null     float64
#  37  beds                                          97 non-null     float64
#  38  amenities                                     100 non-null    object
#  39  price                                         100 non-null    float32
#  40  minimum_nights                                100 non-null    int64
#  41  maximum_nights                                100 non-null    int64
#  42  minimum_minimum_nights                        100 non-null    float64
#  43  maximum_minimum_nights                        100 non-null    float64
#  44  minimum_maximum_nights                        100 non-null    float64
#  45  maximum_maximum_nights                        100 non-null    float64
#  46  minimum_nights_avg_ntm                        100 non-null    float64
#  47  maximum_nights_avg_ntm                        100 non-null    float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              100 non-null    object
#  50  availability_30                               100 non-null    int64
#  51  availability_60                               100 non-null    int64
#  52  availability_90                               100 non-null    int64
#  53  availability_365                              100 non-null    int64
#  54  calendar_last_scraped                         100 non-null    object
#  55  number_of_reviews                             100 non-null    int64
#  56  number_of_reviews_ltm                         100 non-null    int64
#  57  number_of_reviews_l30d                        100 non-null    int64
#  58  first_review                                  100 non-null    object
#  59  last_review                                   100 non-null    object
#  60  review_scores_rating                          100 non-null    float64
#  61  review_scores_accuracy                        44 non-null     float64
#  62  review_scores_cleanliness                     45 non-null     float64
#  63  review_scores_checkin                         44 non-null     float64
#  64  review_scores_communication                   45 non-null     float64
#  65  review_scores_location                        45 non-null     float64
#  66  review_scores_value                           45 non-null     float64
#  67  license                                       0 non-null      object
#  68  instant_bookable                              100 non-null    object
#  69  calculated_host_listings_count                100 non-null    int64
#  70  calculated_host_listings_count_entire_homes   100 non-null    int64
#  71  calculated_host_listings_count_private_rooms  100 non-null    int64
#  72  calculated_host_listings_count_shared_rooms   100 non-null    int64
#  73  reviews_per_month                             100 non-null    float64
# dtypes: float32(1), float64(22), int64(17), object(34)
# memory usage: 58.2+ KB

# %%
top_air["amenities"]=top_air['amenities'].str.replace('[', '').str.replace(']','').str.replace('"','')
top_air["amenities"] =top_air["amenities"].to_frame()
top_air["amenities"].head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/3206109549.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top_air["amenities"]=top_air['amenities'].str.replace('[', '').str.replace(']','').str.replace('"','')
# 1350    TV, Pool, Air conditioning, Gym, Hair dryer, E...
# 949     TV, Pool, Elevator, Cooking basics, Kitchen, E...
# 1220    Air conditioning, Kitchen, Hangers, Elevator, ...
# 2765    TV, Air conditioning, Kitchen, Hangers, Elevat...
# 3665    Heating, Air conditioning, Hangers, Elevator, ...
# Name: amenities, dtype: object

# %%
top_amenities =  pd.DataFrame(''.join(top_air["amenities"]).lower().split(',')).value_counts()
top_amenities = top_air['amenities'].str.split(', ', expand=True).stack().value_counts()[0:10]
top_amenities = top_amenities.rename_axis('amenities').reset_index(name='count')

# %%
top_air["host_verifications"]=top_air['host_verifications'].str.replace('[', '').str.replace(']','').str.replace('"','').str.replace('/', '').str.replace("'", '')
top_air["num_of_veri"]= top_air["host_verifications"].apply(lambda n: len(n.split(',')))
top_air["num_of_veri"] =top_air["num_of_veri"].to_frame()
top_air["num_of_veri"].head()


top_v =  pd.DataFrame(''.join(top_air["host_verifications"]).lower().split(',')).value_counts()
top_v = top_air['host_verifications'].str.split(', ', expand=True).stack().value_counts()[0:10]
top_v = top_v.rename_axis('host_verifications').reset_index(name='count')

f = plt.figure(figsize=(24, 24))
sb.barplot(x='count', y="host_verifications", data=top_v,orient = "h")
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/1280987478.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top_air["host_verifications"]=top_air['host_verifications'].str.replace('[', '').str.replace(']','').str.replace('"','').str.replace('/', '').str.replace("'", '')
# <AxesSubplot:xlabel='count', ylabel='host_verifications'>

# %%
top_air["num_of_amenities"]= air_data["amenities"].apply(lambda n: len(n.split(",")))
top_air["num_of_amenities"].head()
f = plt.figure(figsize=(24, 24))
sb.barplot(x='count', y="amenities", data=top_amenities,orient = "h")
# Out:
# <AxesSubplot:xlabel='count', ylabel='amenities'>

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
print_full(top_amenities)
# Out:
#                  amenities  count
# 0         Air conditioning     96
# 1                     Wifi     96
# 2  Long term stays allowed     96
# 3               Essentials     75
# 4                   Washer     72
# 5                  Hangers     67
# 6      Dedicated workspace     64
# 7                  Kitchen     62
# 8                  Shampoo     61
# 9                       TV     60

# %% [markdown]
# # Property Type of the top Rated places|

# %%
top_air["property_type"]=top_air['property_type'].str.replace('[', '').str.replace(']','').str.replace('"','')
top_air["property_type"] =top_air["property_type"].to_frame()
top_air["property_type"].head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/3712839184.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top_air["property_type"]=top_air['property_type'].str.replace('[', '').str.replace(']','').str.replace('"','')
# 1350               Entire apartment
# 949              Entire condominium
# 1220    Private room in condominium
# 2765    Private room in condominium
# 3665         Room in boutique hotel
# Name: property_type, dtype: object

# %%
top_ptype = top_air['property_type'].str.split(', ', expand=True).stack().value_counts()[0:10]
top_ptype = top_ptype.rename_axis('property_type').reset_index(name='count')

f = plt.figure(figsize=(24, 24))
sb.barplot(x='count', y="property_type", data=top_ptype,orient = "h")
# Out:
# <AxesSubplot:xlabel='count', ylabel='property_type'>

# %%
top_air["neighbourhood_cleansed"]=top_air['neighbourhood_cleansed'].str.replace('[', '').str.replace(']','').str.replace('"','')
top_air["neighbourhood_cleansed"] =top_air["neighbourhood_cleansed"].to_frame()
top_air["neighbourhood_cleansed"].head()

top_neig = top_air['neighbourhood_cleansed'].str.split(', ', expand=True).stack().value_counts()[0:10]
top_neig = top_neig.rename_axis('neighbourhood_cleansed').reset_index(name='count')
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/1639407068.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top_air["neighbourhood_cleansed"]=top_air['neighbourhood_cleansed'].str.replace('[', '').str.replace(']','').str.replace('"','')

# %%
f = plt.figure(figsize=(24, 24))
sb.barplot(x='count', y="neighbourhood_cleansed", data=top_neig,orient = "h")
# Out:
# <AxesSubplot:xlabel='count', ylabel='neighbourhood_cleansed'>

# %%
top_air["name"] = top_air["name"].str.replace(r'<[^<>]*>', ' ', regex=True)
#air_data["description"] = air_data["description"].str.replace(('\?|\|&|•|+|-|'), '',regex=True)
top_air["name"] = top_air["name"].str.replace('\W', ' ', regex=True)
des = pd.DataFrame(top_air["name"])
des["name"] = des["name"].str.replace('\d+', ' ', regex=True)
des.head()
top_words =  pd.DataFrame(' '.join(des["name"]).lower().split()).value_counts()[:50]
top_words = top_words.rename_axis('top_words').reset_index(name='count')
top_words.head()
# Out:
#   top_words  count
# 0      room     36
# 1        in     17
# 2       for     13
# 3       mrt     12
# 4        br     11

# %%
print_full(top_words)
# Out:
#     top_words  count
# 0        room     36
# 1          in     17
# 2         for     13
# 3         mrt     12
# 4          br     11
# 5          to     11
# 6        near     10
# 7      studio     10
# 8       condo     10
# 9     private     10
# 10        bed      9
# 11       cozy      7
# 12     single      7
# 13      hotel      7
# 14         at      6
# 15       view      6
# 16  apartment      6
# 17       city      6
# 18      suite      6
# 19       cosy      6
# 20        the      5
# 21  singapore      5
# 22       with      5
# 23        min      5
# 24       park      5
# 25     master      4
# 26         of      4
# 27     double      4
# 28     novena      4
# 29     family      4
# 30     common      4
# 31     center      4
# 32       king      4
# 33         rm      4
# 34    bedroom      4
# 35     outram      4
# 36       haji      3
# 37    orchard      3
# 38   heritage      3
# 39     luxury      3
# 40   queenbed      3
# 41    explore      3
# 42      prime      3
# 43       nice      3
# 44        rma      3
# 45       lane      3
# 46     deluxe      3
# 47        nus      3
# 48    sentosa      3
# 49          a      3

# %%
#conda install -c conda-forge wordcloud

# %% [markdown]
# # Word Cloud to see most popular words

# %%
from wordcloud import WordCloud

d = dict(zip(top_ptype['property_type'], top_ptype['count']))


wordcloud = WordCloud(background_color="black",width=600, height=600).generate_from_frequencies(d)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = dict(zip(top_neig['neighbourhood_cleansed'], top_neig['count']))


wordcloud = WordCloud(background_color="black",width=1600, height=800).generate_from_frequencies(d)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = dict(zip(top_words['top_words'], top_words['count']))


wordcloud = WordCloud(background_color="black",width=1600, height=800).generate_from_frequencies(d)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # Bar Plots for numerical values

# %%
test = pd.DataFrame(air_data[['price','review_scores_rating']])

# %%
test = pd.DataFrame(air_data[['price','review_scores_rating']])
f = plt.figure(figsize=(24, 24))
sb.boxplot(x='price', y="review_scores_rating", data=test,orient = "h")
# Out:
# <AxesSubplot:xlabel='price', ylabel='review_scores_rating'>

# %%
test = pd.DataFrame(top_air[['num_of_amenities','review_scores_rating']])
f = plt.figure(figsize=(24, 24))
sb.boxplot(x='num_of_amenities', y="review_scores_rating", data=test,orient = "h")
# Out:
# <AxesSubplot:xlabel='num_of_amenities', ylabel='review_scores_rating'>

# %%
test = pd.DataFrame(top_air[['num_of_veri','review_scores_rating']])
f = plt.figure(figsize=(24, 24))
sb.boxplot(x='num_of_veri', y="review_scores_rating", data=test,orient = "h")
# Out:
# <AxesSubplot:xlabel='num_of_veri', ylabel='review_scores_rating'>

# %%
test = pd.DataFrame(top_air[['num_of_veri','review_scores_rating']])
f = plt.figure(figsize=(24, 24))
sb.boxplot(x='num_of_veri', y="review_scores_rating", data=test,orient = "h")
# Out:
# <AxesSubplot:xlabel='num_of_veri', ylabel='review_scores_rating'>

# %% [markdown]
# # Putting price and amenities into the same dataframe to compare

# %%
amenities = zhdf[['price','amenities']]

amenities['price'] = amenities['price'].str.replace(',', '').str.replace('$', '').astype(float)
amenities['amenities'] = amenities['amenities'].apply(str).str.replace('[', '').str.replace(']','').str.replace('"','')

#str.replace(' ','')
#amenities = amenities.to_frame()

amenities.head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/2700618335.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   amenities['price'] = amenities['price'].str.replace(',', '').str.replace('$', '').astype(float)
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/2700618335.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amenities['price'] = amenities['price'].str.replace(',', '').str.replace('$', '').astype(float)
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/2700618335.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   amenities['amenities'] = amenities['amenities'].apply(str).str.replace('[', '').str.replace(']','').str.replace('"','')
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/2700618335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amenities['amenities'] = amenities['amenities'].apply(str).str.replace('[', '').str.replace(']','').str.replace('"','')
#    price                                          amenities
# 0   81.0  Air conditioning, Elevator, Wifi, Long term st...
# 1   80.0  Air conditioning, Kitchen, Elevator, Wifi, Gym...
# 2   67.0  Air conditioning, Kitchen, Elevator, Wifi, Cab...
# 3  177.0  Wifi, Washer, Kitchen, Long term stays allowed...
# 4   81.0  Wifi, Washer, Kitchen, Long term stays allowed...

# %% [markdown]
# # Check count of how many amenities are there in total

# %%
amenities['amenities'] = amenities['amenities'].str.decode('unicode_escape')
a = amenities['amenities'].str.split(', ', expand=True).stack().value_counts()
test_df = a.rename_axis('amenities').reset_index(name='count')
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/3105268720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amenities['amenities'] = amenities['amenities'].str.decode('unicode_escape')

# %%
print_full(test_df)
# Out:
#                                              amenities  count
# 0                              Long term stays allowed   4157
# 1                                     Air conditioning   4107
# 2                                                 Wifi   4086
# 3                                           Essentials   3641
# 4                                               Washer   3603
# 5                                              Hangers   3432
# 6                                              Kitchen   3335
# 7                                                 Iron   3247
# 8                                  Dedicated workspace   3186
# 9                                           Hair dryer   3004
# 10                                               Dryer   2794
# 11                                           Hot water   2697
# 12                                             Shampoo   2670
# 13                                        Refrigerator   2217
# 14                                            Elevator   2147
# 15                                                  TV   2138
# 16                                                Pool   2102
# 17                                           Microwave   2015
# 18                               Dishes and silverware   1984
# 19                                          Bed linens   1906
# 20                                      Cooking basics   1772
# 21                                         Smoke alarm   1735
# 22                                                 Gym   1731
# 23                                               Stove   1682
# 24                                   Fire extinguisher   1681
# 25                                Lock on bedroom door   1562
# 26                                             Heating   1360
# 27                                    Private entrance   1360
# 28                             Luggage dropoff allowed   1259
# 29                            Free parking on premises   1181
# 30                          Extra pillows and blankets   1143
# 31                                                Oven   1134
# 32                                       First aid kit    999
# 33                                            Cable TV    929
# 34                              TV with standard cable    928
# 35                           Paid parking off premises    860
# 36                                   Single level home    682
# 37                                    Patio or balcony    651
# 38                                          Shower gel    648
# 39                                     Host greets you    633
# 40                               Carbon monoxide alarm    632
# 41                            Paid parking on premises    562
# 42                                           Breakfast    499
# 43                                            Backyard    476
# 44                                              Keypad    472
# 45                                 Free street parking    470
# 46                        Security cameras on property    454
# 47                                           BBQ grill    441
# 48                                                Crib    440
# 49                                          High chair    364
# 50                                      Building staff    339
# 51                                             Hot tub    325
# 52                                        Coffee maker    261
# 53                            Pack ’n Play/travel crib    244
# 54                            Cleaning before checkout    204
# 55                                             Bathtub    190
# 56                                           Body soap    167
# 57                                    Hot water kettle    160
# 58                                 Ethernet connection    154
# 59                                          Dishwasher    149
# 60                               Room-darkening shades    116
# 61                                    Indoor fireplace    101
# 62                                             Lockbox    101
# 63                                        Dining table     99
# 64                                             Freezer     98
# 65                                         Conditioner     95
# 66                                   Cleaning products     77
# 67                                           Baby bath     76
# 68                            Drying rack for clothing     74
# 69                          Babysitter recommendations     72
# 70                                          Smart lock     68
# 71                                   Laundromat nearby     54
# 72                               Children’s dinnerware     52
# 73                                               Bidet     51
# 74                           Children’s books and toys     49
# 75                                             Toaster     49
# 76                                         Pocket wifi     46
# 77                                          Rice maker     45
# 78                                        Wine glasses     44
# 79                                    Clothing storage     41
# 80                                                Safe     40
# 81                                       Window guards     38
# 82                                         Ceiling fan     35
# 83                                          Waterfront     33
# 84                                          Beachfront     33
# 85                                        Game console     33
# 86                                         Lake access     32
# 87                                         Shared pool     32
# 88                                       Portable fans     27
# 89                            Clothing storage: closet     24
# 90                                         Mini fridge     23
# 91                                   Outdoor furniture     21
# 92                                   Barbecue utensils     19
# 93                                 Dryer – In building     16
# 94                                    Beach essentials     16
# 95                    Paid street parking off premises     16
# 96                                Washer – In building     15
# 97                                        Sound system     15
# 98                                 Outdoor dining area     13
# 99                                       Outlet covers     12
# 100                                   Washer – In unit     12
# 101                                  Nespresso machine     11
# 102                                         EV charger     10
# 103                                    Induction stove     10
# 104                                        Bread maker     10
# 105                          Shared garden or backyard      9
# 106                       Paid parking lot on premises      9
# 107                                       Baking sheet      9
# 108                               Free dryer – In unit      9
# 109                                       Shared sauna      8
# 110                                              Sauna      7
# 111                              Free washer – In unit      7
# 112                                     Electric stove      7
# 113                                    Dryer – In unit      7
# 114                   Paid parking garage off premises      6
# 115                                         Pool table      6
# 116                                     Outdoor shower      6
# 117                                        Board games      6
# 118                                     Changing table      6
# 119                                   Wifi – 1000 Mbps      5
# 120              Shared outdoor olympic-sized lap pool      5
# 121                                              Bikes      5
# 122                      Paid parking lot off premises      5
# 123                                       Baby monitor      4
# 124                           Central air conditioning      4
# 125               Clothing storage: dresser and closet      4
# 126                    Paid parking garage on premises      4
# 127                                Table corner guards      4
# 128              Clothing storage: wardrobe and closet      3
# 129               Clothing storage: closet and dresser      3
# 130                                  Baby safety gates      3
# 131                                   Fireplace guards      3
# 132                                      Record player      3
# 133                                   Pour-over coffee      3
# 134                               Stainless steel oven      3
# 135                                           Fire pit      3
# 136             Paid parking lot on premises – 1 space      3
# 137                           Private patio or balcony      3
# 138                                               HDTV      3
# 139                              Keurig coffee machine      2
# 140                                              Piano      2
# 141                                    Trash compactor      2
# 142                                    Ping pong table      2
# 143                            Shared outdoor lap pool      2
# 144                         Dedicated workspace: table      2
# 145                                   TV with Apple TV      2
# 146                    Free parking garage on premises      2
# 147                               Shokobutsu body soap      2
# 148                         Clothing storage: wardrobe      2
# 149                                          Gas stove      2
# 150                                       Mosquito net      2
# 151                          Dedicated workspace: desk      2
# 152                                         Toiletries      1
# 153                             24-hour fitness center      1
# 154                         Complimentary self parking      1
# 155                      Limited housekeeping — weekly      1
# 156                                          Free wifi      1
# 157                                             linens      1
# 158                       Dedicated workspace: monitor      1
# 159                                        Kitchenette      1
# 160                  Private fenced garden or backyard      1
# 161                                      Entrée privée      1
# 162                                         Télévision      1
# 163                                         Shampooing      1
# 164                                            Cuisine      1
# 165                            Kit de premiers secours      1
# 166                   Détecteur de monoxyde de carbone      1
# 167                                 Détecteur de fumée      1
# 168                           55\ HDTV with Chromecast      1
# 169                                      Private sauna      1
# 170                                   Laundry services      1
# 171                             Essential  conditioner      1
# 172                     Séjours longue durée autorisés      1
# 173                                           and desk      1
# 174                                   Techno gas stove      1
# 175                     Sharp and Hitachi refrigerator      1
# 176                               Samsung refrigerator      1
# 177                             Shared gym in building      1
# 178                Sound system with Bluetooth and aux      1
# 179  Children’s books and toys for ages 5-10 years old      1
# 180                                   and office chair      1
# 181                                         Shared gym      1
# 182                                  Game console: PS4      1
# 183                Free residential garage on premises      1
# 184                                               desk      1
# 185                                       office chair      1
# 186                   Clothing storage: walk-in closet      1
# 187                                         Extincteur      1
# 188                          Paid washer – In building      1
# 189                                         Lave-linge      1
# 190                                            Cintres      1
# 191                             40\ TV with Chromecast      1
# 192                               Paid dryer – In unit      1
# 193                                             22\ TV      1
# 194                              Paid washer – In unit      1
# 195                                    TV with Netflix      1
# 196                                           32\ HDTV      1
# 197                  Shared outdoor olympic-sized pool      1
# 198                                    Private hot tub      1
# 199                     Stainless steel electric stove      1
# 200                   Shared fenced garden or backyard      1
# 201                                    Wifi – 500 Mbps      1
# 202                              Sound system with aux      1
# 203                           Free dryer – In building      1
# 204                          Free washer – In building      1
# 205                                  Essential shampoo      1
# 206                              Essential conditioner      1
# 207                                Shared outdoor pool      1
# 208                                     Ski-in/Ski-out      1
# 209                                    LG refrigerator      1
# 210                Dedicated workspace: table and desk      1
# 211                                     Window AC unit      1
# 212                                      Climatisation      1
# 213                          Parking gratuit sur place      1
# 214                                     Fer à repasser      1
# 215                    Porte de la chambre avec verrou      1
# 216                                          Chauffage      1
# 217                                Équipements de base      1
# 218                            Espace de travail dédié      1
# 219                                 Miele refrigerator      1
# 220                        Shared outdoor rooftop pool      1
# 221                                         Miele oven      1
# 222                                            HBO Max      1
# 223                                     standard cable      1
# 224                                         Chromecast      1
# 225                                 Amazon Prime Video      1
# 226                                           Apple TV      1
# 227                              50\ HDTV with Netflix      1
# 228                                 Essential  shampoo      1

# %% [markdown]
# # Bar graph of amenity count

# %%
sb.barplot(y=test_df['amenities'].head(15), x=test_df['count'].head(15), orient='h')
# Out:
# <AxesSubplot:xlabel='count', ylabel='amenities'>

# %% [markdown]
# # Put price and rating into same dataframe to compare

# %%
pricedf = zhdf[['price', 'review_scores_rating']]
pricedf.head()
# Out:
#      price  review_scores_rating
# 0   $81.00                  5.00
# 1   $80.00                  4.56
# 2   $67.00                  4.88
# 3  $177.00                  4.44
# 4   $81.00                  4.16

# %%
#remove extra unnecessary symbols and change price to float
pricedf['price'] = pricedf['price'].str.replace(',', '').str.replace('$', '').astype(float)
pricedf.head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/1771786605.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pricedf['price'] = pricedf['price'].str.replace(',', '').str.replace('$', '').astype(float)
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/1771786605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedf['price'] = pricedf['price'].str.replace(',', '').str.replace('$', '').astype(float)
#    price  review_scores_rating
# 0   81.0                  5.00
# 1   80.0                  4.56
# 2   67.0                  4.88
# 3  177.0                  4.44
# 4   81.0                  4.16

# %% [markdown]
# # Plot ratings against price

# %%
plt.figure(figsize=(10,10))
plt.scatter(pricedf['review_scores_rating'], pricedf['price'])

# %%
test_df.head()
# Out:
#                  amenities  count
# 0  Long term stays allowed   4157
# 1         Air conditioning   4107
# 2                     Wifi   4086
# 3               Essentials   3641
# 4                   Washer   3603

# %% [markdown]
# # Count number of amenities PER listing

# %%
amenities['amenities_count'] = amenities['amenities'].str.split(', ').apply(len)
amenities.head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/2564024349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amenities['amenities_count'] = amenities['amenities'].str.split(', ').apply(len)
#    price                                          amenities  amenities_count
# 0   81.0  Air conditioning, Elevator, Wifi, Long term st...                7
# 1   80.0  Air conditioning, Kitchen, Elevator, Wifi, Gym...               12
# 2   67.0  Air conditioning, Kitchen, Elevator, Wifi, Cab...                8
# 3  177.0  Wifi, Washer, Kitchen, Long term stays allowed...               25
# 4   81.0  Wifi, Washer, Kitchen, Long term stays allowed...               21

# %% [markdown]
# # Regression plot for price against amenities count per listing

# %%
plt.figure(figsize=(10,10))
sb.scatterplot(y=amenities['price'], x=amenities['amenities_count'])
# Out:
# <AxesSubplot:xlabel='amenities_count', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sb.regplot(y=amenities['price'], x=amenities['amenities_count'], line_kws={"color":"r","alpha":0.7,"lw":5})
# Out:
# <AxesSubplot:xlabel='amenities_count', ylabel='price'>

# %%
jointDF = pd.concat([amenities['price'], amenities['amenities_count']], axis = 1)
jointDF.corr()
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot=True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
amenities.insert(1, 'review_scores_rating', zhdf['review_scores_rating'])
amenities.head()
# Out:
#    price  review_scores_rating  \
# 0   81.0                  5.00
# 1   80.0                  4.56
# 2   67.0                  4.88
# 3  177.0                  4.44
# 4   81.0                  4.16
#
#                                            amenities  amenities_count
# 0  Air conditioning, Elevator, Wifi, Long term st...                7
# 1  Air conditioning, Kitchen, Elevator, Wifi, Gym...               12
# 2  Air conditioning, Kitchen, Elevator, Wifi, Cab...                8
# 3  Wifi, Washer, Kitchen, Long term stays allowed...               25
# 4  Wifi, Washer, Kitchen, Long term stays allowed...               21

# %% [markdown]
# # Scatter plot of amenity count against ratings

# %%
plt.figure(figsize=(10,10))
sb.scatterplot(x=amenities['review_scores_rating'], y=amenities['amenities_count'])
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='amenities_count'>

# %%
plt.figure(figsize=(10,10))
sb.regplot(x=amenities['review_scores_rating'], y=amenities['amenities_count'], line_kws={"color":"r","alpha":0.7,"lw":5})
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='amenities_count'>

# %%
jointDF = pd.concat([amenities['review_scores_rating'], amenities['amenities_count']], axis = 1)
jointDF.corr()
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot=True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
amenity_list_top = test_df['amenities'].head(15)
print(amenity_list_top)
# Out:
# 0     Long term stays allowed
# 1            Air conditioning
# 2                        Wifi
# 3                  Essentials
# 4                      Washer
# 5                     Hangers
# 6                     Kitchen
# 7                        Iron
# 8         Dedicated workspace
# 9                  Hair dryer
# 10                      Dryer
# 11                  Hot water
# 12                    Shampoo
# 13               Refrigerator
# 14                   Elevator
# Name: amenities, dtype: object

# %%
#check amenity list against amenity column to see if it exists, then
#then append column to dataframe

for i in amenity_list_top:
    amenities['has_{variable}'.format(variable=i.lower().strip())] = amenities['amenities'].apply(lambda x: str(i) in str(amenities['amenities']))
    
amenities.head()
# Out:
# C:\Users\limzi\AppData\Local\Temp/ipykernel_1728/1343124337.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amenities['has_{variable}'.format(variable=i.lower().strip())] = amenities['amenities'].apply(lambda x: str(i) in str(amenities['amenities']))
#    price  review_scores_rating  \
# 0   81.0                  5.00
# 1   80.0                  4.56
# 2   67.0                  4.88
# 3  177.0                  4.44
# 4   81.0                  4.16
#
#                                            amenities  amenities_count  \
# 0  Air conditioning, Elevator, Wifi, Long term st...                7
# 1  Air conditioning, Kitchen, Elevator, Wifi, Gym...               12
# 2  Air conditioning, Kitchen, Elevator, Wifi, Cab...                8
# 3  Wifi, Washer, Kitchen, Long term stays allowed...               25
# 4  Wifi, Washer, Kitchen, Long term stays allowed...               21
#
#    has_long term stays allowed  has_air conditioning  has_wifi  \
# 0                         True                  True      True
# 1                         True                  True      True
# 2                         True                  True      True
# 3                         True                  True      True
# 4                         True                  True      True
#
#    has_essentials  has_washer  has_hangers  has_kitchen  has_iron  \
# 0           False        True         True         True     False
# 1           False        True         True         True     False
# 2           False        True         True         True     False
# 3           False        True         True         True     False
# 4           False        True         True         True     False
#
#    has_dedicated workspace  has_hair dryer  has_dryer  has_hot water  \
# 0                    False           False      False           True
# 1                    False           False      False           True
# 2                    False           False      False           True
# 3                    False           False      False           True
# 4                    False           False      False           True
#
#    has_shampoo  has_refrigerator  has_elevator
# 0        False             False          True
# 1        False             False          True
# 2        False             False          True
# 3        False             False          True
# 4        False             False          True
